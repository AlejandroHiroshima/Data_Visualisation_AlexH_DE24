# %% [markdown]
# # `Matplotlib annotations`

# %%
import pandas as pd
import duckdb

df = pd.read_csv("data/1900-census-immigrant-pop-metro.csv")

df.head()
# Out:
#         City         State  Error Total foreign born  Africa  \
# 0      Akron          Ohio      0              7,127     4.0
# 1     Albany      New York     55             17,718     3.0
# 2  Allegheny  Pennsylvania      0             30,216     4.0
# 3  Allentown  Pennsylvania      3              2,991     NaN
# 4    Altoona  Pennsylvania     65              3,301     2.0
#
#    Asia (except China, Japan, and India) Atlantic Islands Australia Austria  \
# 0                                    NaN              NaN         1     190
# 1                                   39.0                4        13     106
# 2                                    5.0                2         8   3,929
# 3                                    1.0              NaN         2     337
# 4                                    7.0              NaN       NaN      57
#
#   Belgium  ... Scotland South America Spain  Sweden Switzerland Turkey Wales  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 50 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   City                                         161 non-null    object
#  1   State                                        161 non-null    object
#  2   Error                                        161 non-null    int64
#  3   Total foreign born                           161 non-null    object
#  4   Africa                                       120 non-null    float64
#  5   Asia (except China, Japan, and India)        133 non-null    float64
#  6   Atlantic Islands                             99 non-null     object
#  7   Australia                                    136 non-null    object
#  8   Austria                                      161 non-null    object
# ...

# %%
df["Total foreign born"].iloc[0]
# Out:
# '7,127'

# %%
df_nordic = df[["Sweden","Norway","Finland", "Denmark", "Total foreign born"]]
df_nordic.head()
# Out:
#   Sweden Norway Finland Denmark Total foreign born
# 0    200     59       1     105              7,127
# 1     65     12       3      21             17,718
# 2    186      9       5      15             30,216
# 3      5      2     NaN       5              2,991
# 4     32      4       3       5              3,301

# %%
columns = ["Sweden","Norway","Finland", "Denmark", "Total foreign born"]

df_nordic = df[columns]
df_nordic.head()
# Out:
#   Sweden Norway Finland Denmark Total foreign born
# 0    200     59       1     105              7,127
# 1     65     12       3      21             17,718
# 2    186      9       5      15             30,216
# 3      5      2     NaN       5              2,991
# 4     32      4       3       5              3,301

# %%
df_nordic=df_nordic.fillna("0")

# %%
for column in columns:
    df[column] = df_nordic[column].str.replace(",", "").astype(int)

df_nordic
# Out:
#     Sweden Norway Finland Denmark Total foreign born
# 0      200     59       1     105              7,127
# 1       65     12       3      21             17,718
# 2      186      9       5      15             30,216
# 3        5      2       0       5              2,991
# 4       32      4       3       5              3,301
# ..     ...    ...     ...     ...                ...
# 156     45      2      52       3             12,518
# 157  7,542    269   1,143     153             37,652
# 158    289     46       6      81             14,634
# 159     10      1       0       0              1,304
# 160    343     14      28      27             12,207
#
# [161 rows x 5 columns]

# %%
import pandas as pd 
import duckdb

df = pd.read_csv("data/1900-census-immigrant-pop-metro.csv")

columns = ["Sweden", "Norway", "Finland", "Denmark", "Total foreign born"]

df_nordic = df[columns]

df_nordic = df_nordic.fillna("0")

for column in columns:
    df[column] = df_nordic[column].str.replace(",", "").astype(int)

# %%
df[columns].info()
df_nordic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Sweden              161 non-null    int64
#  1   Norway              161 non-null    int64
#  2   Finland             161 non-null    int64
#  3   Denmark             161 non-null    int64
#  4   Total foreign born  161 non-null    int64
# dtypes: int64(5)
# memory usage: 6.4 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Sweden              161 non-null    object
#  1   Norway              161 non-null    object
#  2   Finland             161 non-null    object
#  3   Denmark             161 non-null    object
#  4   Total foreign born  161 non-null    object
# dtypes: object(5)
# memory usage: 6.4+ KB

# %%
df_nordic = duckdb.query(
    """--sql
    WITH nordic AS (
        FROM df
            SELECT
                state,
                SUM("Total foreign born") AS "Total foreigners",
                SUM(Sweden) AS Swedes,
                SUM(Norway) AS Norweigans,
                SUM(denmark) AS Danish,
                SUM(Finland) AS Finnish
            GROUP BY 
                state
            )
            FROM nordic n
            SELECT *, n.swedes + n.norweigans + n.danish + n.finnish AS Nordic
            ORDER BY nordic DESC
 """).df()

df_nordic
# Out:
#                    State  Total foreigners   Swedes  Norweigans   Danish  \
# 0               Illinois          627465.0  57158.0     22300.0  10374.0
# 1              Minnesota          128823.0  34984.0     17087.0   2975.0
# 2               New York         1521931.0  29961.0     11752.0   6186.0
# 3          Massachusetts          567170.0  21971.0      2366.0   1451.0
# 4              Wisconsin          124230.0   4034.0      6485.0   4024.0
# 5             California          160828.0   7223.0      2729.0   3082.0
# 6             Washington           40868.0   5150.0      3686.0   1193.0
# 7           Pennsylvania          514506.0   5986.0       861.0   1210.0
# 8               Nebraska           34456.0   4864.0       457.0   2888.0
# 9            Connecticut          101502.0   6647.0       273.0   1144.0
# 10                  Iowa           38173.0   4222.0      1519.0   1957.0
# 11            New Jersey          258498.0   2750.0      1483.0   1061.0
# ...

# %%
df_nordic.shape
# Out:
# (39, 7)

# %%
import matplotlib.pyplot as plt

top3_nordic = df_nordic.drop(["Total foreigners", "Nordic"], axis=1).set_index("State").iloc[:3]
top3_nordic
# Out:
#             Swedes  Norweigans   Danish  Finnish
# State
# Illinois   57158.0     22300.0  10374.0    447.0
# Minnesota  34984.0     17087.0   2975.0   1101.0
# New York   29961.0     11752.0   6186.0   3764.0

# %%
def nordic_plot():
    ax=top3_nordic.plot(kind="bar", figsize=(12,6))
    ax.set_xticklabels(top3_nordic.index, rotation=0)
    fig=ax.get_figure()
    
    return fig, ax

nordic_plot()
# Out:
# (<Figure size 1200x600 with 1 Axes>, <Axes: xlabel='State'>)

# %%
fig,ax = nordic_plot()

ax.containers
# Out:
# [<BarContainer object of 3 artists>,
#  <BarContainer object of 3 artists>,
#  <BarContainer object of 3 artists>,
#  <BarContainer object of 3 artists>]

# %%
ax.containers[0][0] # Swedes i illinois

# %%
ax.containers[0][1].get_height(),ax.containers[0][1].get_x() # höjden och x för Swedes i Minnesota
# Out:
# (np.float64(34984.0), np.float64(0.75))

# %% [markdown]
# ## Annotations

# %%
fig, ax = nordic_plot()
arrowprops= dict(arrowstyle = "->", linewidth = 2, connectionstyle = "arc3, rad=.4")
ax.annotate(text= "Swedes", xy= (0.8, 35000), arrowprops=arrowprops, xytext=(0.8, 43000))
# Out:
# Text(0.8, 43000, 'Swedes')

# %%
fig, ax = nordic_plot()
ax.legend().remove()
swede_bars, norweigan_bars, danish_bars, finnish_bars = ax.containers

def annotate_nordic(bar_artist, text, x_offset, y_offset):
    xy=(bar_artist.get_x(), bar_artist.get_height())
    rad = .3 if xy[0] < 0 else -.3
    arrowprops= dict(arrowstyle = "->", linewidth = 2, connectionstyle = f"arc3, rad={rad}")
    ax.annotate(text= text, xy= (xy[0] + .06, xy[1]), arrowprops=arrowprops, xytext=(xy[0] + x_offset, xy[1]+ y_offset))

annotate_nordic(swede_bars[1],"Swedes", -0.1, 7000)
annotate_nordic(norweigan_bars[0],"Norweigans", 0.1, 5500)
annotate_nordic(danish_bars[1],"Danish", 0.1, 7500)
annotate_nordic(finnish_bars[2],"Finnish", -0.1, 9000)
fig.savefig("nordic_annotations.png")
